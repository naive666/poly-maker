# %%
import requests
from datetime import datetime, timezone

sports = requests.get("https://gamma-api.polymarket.com/sports", timeout=20).json()
names = [item["sport"] for item in sports if isinstance(item, dict) and "sport" in item]
print(names)
# Out:
# ['ncaab', 'epl', 'lal', 'cbb', 'ipl', 'wnba', 'bun', 'mlb', 'cfb', 'nfl', 'fl1', 'sea', 'ucl', 'afc', 'ofc', 'fif', 'ere', 'arg', 'itc', 'mex', 'lcs', 'lib', 'sud', 'tur', 'con', 'cof', 'uef', 'caf', 'rus', 'efa', 'efl', 'mls', 'nba', 'nhl', 'uel', 'dota2', 'lol', 'valorant', 'odi', 't20', 'cs2', 'abb', 'csa', 'atp', 'wta', 'cwbb', 'mma', 'cdr', 'mlbb', 'ow', 'kog', 'codmw', 'fifa', 'lol-wild-rift', 'pubg', 'r6siege', 'rl', 'starcraft-2', 'starcraft-brood-war', 'col', 'cde', 'dfb', 'bra', 'jap', 'ja2', 'kor', 'spl', 'chi', 'aus', 'ind', 'nor', 'den', 'por', 'test', 'she', 'sasa', 'lpl', 'psp', 'kbo', 'shl', 'cehl', 'dehl', 'snhl', 'khl', 'ahl']

# %%
import requests, itertools

BASE = "https://gamma-api.polymarket.com"

def list_series(limit=100, offset=0, closed=None, order=None, ascending=None):
    params = {"limit": limit, "offset": offset}
    if closed is not None:
        params["closed"] = str(closed).lower()
    if order:
        params["order"] = order
    if ascending is not None:
        params["ascending"] = str(ascending).lower()
    r = requests.get(f"{BASE}/series", params=params, timeout=30)
    r.raise_for_status()
    return r.json()  # top-level LIST

series = list_series(limit=50)
print(f"Series returned: {len(series)}")

# Flatten the nested markets (events → markets), if present
def iter_markets_from_series(series_obj):
    for ev in series_obj.get("events", []) or []:
        for m in ev.get("markets", []) or []:
            yield m

all_markets = list(itertools.chain.from_iterable(
    iter_markets_from_series(s) for s in series if isinstance(s, dict)
))
print("Embedded markets found:", len(all_markets))
for m in all_markets[:5]:
    print("•", m.get("question"))
# Out:
# Series returned: 50
# Embedded markets found: 0

# %%
def get_markets_by_tag_id(tag_id, closed=False, limit=250, max_pages=20):
    all_markets = []
    for page in range(max_pages):
        offset = page * limit
        params = {"tag_id": tag_id, "closed": str(closed).lower(), "limit": limit, "offset": offset}
        r = requests.get(f"{BASE}/markets", params=params, timeout=30)
        r.raise_for_status()
        chunk = r.json()
        markets = chunk if isinstance(chunk, list) else chunk.get("markets", chunk)
        # docs show /markets returns a list; some SDKs wrap it. Handle both.
        if not markets:
            break
        all_markets.extend(markets)
        if len(markets) < limit:
            break
    return all_markets

def get_alive_market(all_mkt):
    alive = [m for m in all_mkt if m.get('active') is True and m.get("acceptingOrders") is True]
    want_types = {"moneyline", "spread", "total"}  # example
    typed = [m for m in alive if str(m.get("sportsMarketType","")).lower() in want_types]
    print("Alive (selected types):", len(typed))
    return typed

# %%
def get_sport_tag_id(sport_name: str) -> str:
    """
    Fetch the Polymarket sport tagId for a given sport, e.g. 'EPL', 'NBA', 'NFL'.
    """
    sports = requests.get(f"{BASE}/sports", timeout=20).json()
    # items = sports.get("sports", [])

    for s in sports:
        if s.get("sport", "").upper() == sport_name.upper():    
            tag = s['tags'].split(',')[1]        
            return int(tag)

    raise ValueError(f"Sport '{sport_name}' not found.")

# %%
markets = requests.get(
        f"{BASE}/tags/{45}",
        timeout=20
    ).json()

# %%
markets
# Out:
# {'id': '45',
#  'label': 'trail blazers',
#  'slug': 'trail-blazers',
#  'publishedAt': '2023-11-02 21:13:49.657+00',
#  'createdAt': '2023-11-02T21:13:49.664Z',
#  'updatedAt': '2023-11-02T21:13:49.664Z'}

# %%
epl_markets = get_sport_tag_id("epl")
nba_markets = get_sport_tag_id("nba")

# %%
nhl_markets = get_sport_tag_id("nhl")

# %%
nhl_markets
# Out:
# 899

# %%
sport_tag_id = 899 # int(spprt_tag["id"])    
all_mkt = get_markets_by_tag_id(sport_tag_id, closed=False, limit=250)
alive_mkt = get_alive_market(all_mkt)
# Out:
# Alive (selected types): 199

# %%
alive_mkt
# Out:
# [{'id': '605042',
#   'question': 'Oilers vs. Flames',
#   'conditionId': '0x1ec664b73bf312e2a2ca693deb94e126dd74b5dfa44bc9cedf1e8129ebe8652a',
#   'slug': 'nhl-edm-cgy-2025-09-21',
#   'resolutionSource': 'https://www.nhl.com/scores',
#   'endDate': '2025-09-22T00:00:00Z',
#   'liquidity': '8.8631',
#   'startDate': '2025-09-20T06:22:02.212099Z',
#   'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#   'description': 'In the upcoming NHL game, scheduled for September 21 at 8:00PM ET:\nIf the Oilers, the market will resolve to "Oilers".\nIf the Flames, the market will resolve to "Flames".\nIf the game is postponed, this market will remain open until the game has been completed.\nIf the game is canceled entirely, with no make-up game, this market will resolve 50-50.',
#   'outcomes': '["Oilers", "Flames"]',
#   'outcomePrices': '["0.49", "0.51"]',
#   'volume': '513.897752',
#   'active': True,
#   'closed': False,
#   'marketMakerAddress': '',
#   'createdAt': '2025-09-20T06:20:47.807041Z',
#   'updatedAt': '2025-12-01T00:19:35.131863Z',
#   'new': False,
#   'featured': False,
#   'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5',
#   'archived': False,
#   'resolvedBy': '0x65070BE91477460D8A7AeEb94ef92fe056C2f2A7',
#   'restricted': True,
#   'groupItemThreshold': '0',
#   'questionID': '0x2a19d7739a45ba64d79083143e78b98211f29b92a14a04d6ceb3311672cde337',
#   'enableOrderBook': True,
#   'orderPriceMinTickSize': 0.01,
#   'orderMinSize': 5,
#   'volumeNum': 513.897752,
#   'liquidityNum': 8.8631,
#   'endDateIso': '2025-09-22',
#   'startDateIso': '2025-09-20',
#   'hasReviewedDates': True,
#   'volume1wk': 1.05262,
#   'volume1mo': 4.29262,
#   'volume1yr': 513.897752,
#   'gameStartTime': '2025-09-22 00:00:00+00',
#   'secondsDelay': 3,
#   'clobTokenIds': '["52205886726417997587062732777226140886318278712083909477105055938757753833806", "55605869039173595146985121120073582626202060075897859340246557957762365711817"]',
#   'umaBond': '500',
#   'umaReward': '2',
#   'volume1wkClob': 1.05262,
#   'volume1moClob': 4.29262,
#   'volume1yrClob': 513.897752,
#   'volumeClob': 513.897752,
#   'liquidityClob': 8.8631,
#   'customLiveness': 0,
#   'acceptingOrders': True,
#   'negRisk': False,
#   'negRiskRequestID': '',
#   'events': [{'id': '47061',
#     'ticker': 'nhl-edm-cgy-2025-09-21',
#     'slug': 'nhl-edm-cgy-2025-09-21',
#     'title': 'Oilers vs. Flames',
#     'description': 'In the upcoming NHL game, scheduled for September 21 at 8:00PM ET:\nIf the Oilers, the market will resolve to "Oilers".\nIf the Flames, the market will resolve to "Flames".\nIf the game is postponed, this market will remain open until the game has been completed.\nIf the game is canceled entirely, with no make-up game, this market will resolve 50-50.',
#     'resolutionSource': 'https://www.nhl.com/scores',
#     'startDate': '2025-09-20T06:23:20.860618Z',
#     'creationDate': '2025-09-22T00:00:00Z',
#     'endDate': '2025-09-22T00:00:00Z',
#     'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#     'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#     'active': True,
#     'closed': False,
#     'archived': False,
#     'new': False,
#     'featured': False,
#     'restricted': True,
#     'liquidity': 8.8631,
#     'volume': 513.897752,
#     'openInterest': 0,
#     'createdAt': '2025-09-20T06:20:47.702057Z',
#     'updatedAt': '2025-12-01T00:21:11.937864Z',
#     'competitive': 0.07999200079992001,
#     'volume1wk': 1.05262,
#     'volume1mo': 4.29262,
#     'volume1yr': 513.897752,
#     'enableOrderBook': True,
#     'liquidityClob': 8.8631,
#     'negRisk': False,
#     'commentCount': 0,
#     'cyom': False,
#     'showAllOutcomes': True,
#     'showMarketImages': False,
#     'enableNegRisk': False,
#     'automaticallyActive': True,
#     'eventDate': '2025-09-21',
#     'eventWeek': 50,
#     'negRiskAugmented': False,
#     'pendingDeployment': False,
#     'deploying': False,
#     'gameId': 23946}],
#   'ready': False,
#   'funded': False,
#   'acceptingOrdersTimestamp': '2025-09-20T06:21:40Z',
#   'cyom': False,
#   'competitive': 0.07999200079992001,
#   'pagerDutyNotificationEnabled': False,
#   'approved': True,
#   'rewardsMinSize': 0,
#   'rewardsMaxSpread': 0,
#   'spread': 0.92,
#   'oneHourPriceChange': -0.005,
#   'oneWeekPriceChange': -0.005,
#   'oneMonthPriceChange': -0.02,
#   'lastTradePrice': 0.95,
#   'bestBid': 0.03,
#   'bestAsk': 0.95,
#   'automaticallyActive': True,
#   'clearBookOnStart': True,
#   'manualActivation': False,
#   'negRiskOther': False,
#   'sportsMarketType': 'moneyline',
#   'umaResolutionStatuses': '[]',
#   'pendingDeployment': False,
#   'deploying': False,
#   'deployingTimestamp': '2025-09-20T06:21:04.875213Z',
#   'rfqEnabled': False,
#   'holdingRewardsEnabled': False,
#   'feesEnabled': False},
#  {'id': '662228',
#   'question': 'Ducks vs. Blackhawks',
#   'conditionId': '0xb41043e89d67c4c6b679c238f7672643a1d34c85fda62e281f7fab5e951bd9b4',
#   'slug': 'nhl-ana-chi-2025-11-30',
#   'resolutionSource': 'https://www.nhl.com/scores',
#   'endDate': '2025-11-30T15:30:00Z',
#   'liquidity': '377915.04324',
#   'startDate': '2025-11-03T16:31:23.082016Z',
#   'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#   'description': 'In the upcoming NHL game, scheduled for November 30 at 10:30AM ET:\nIf the Ducks win, the market will resolve to "Ducks".\nIf the Blackhawks win, the market will resolve to "Blackhawks".\nIf the game is postponed, this market will remain open until the game has been completed.\nIf the game is canceled entirely, with no make-up game, this market will resolve 50-50.\nThe result will be determined based on the final score including any overtime periods and shootouts. In the event of a shootout, one goal will be added to the winning team\'s score for the purpose of resolution.',
#   'outcomes': '["Ducks", "Blackhawks"]',
#   'outcomePrices': '["0.0005", "0.9995"]',
#   'volume': '989915.016405',
#   'active': True,
#   'closed': False,
#   'marketMakerAddress': '',
#   'createdAt': '2025-11-03T16:30:17.209116Z',
#   'updatedAt': '2025-12-01T00:27:02.946672Z',
#   'new': False,
#   'featured': False,
#   'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5',
#   'archived': False,
#   'resolvedBy': '0x65070BE91477460D8A7AeEb94ef92fe056C2f2A7',
#   'restricted': True,
#   'groupItemThreshold': '0',
#   'questionID': '0x0eb24e4c51a6303ac41a6d34d81854baba5647124f3efe3dd0668764eb8a61b8',
#   'enableOrderBook': True,
#   'orderPriceMinTickSize': 0.001,
#   'orderMinSize': 5,
#   'umaResolutionStatus': 'proposed',
#   'volumeNum': 989915.016405,
#   'liquidityNum': 377915.04324,
#   'endDateIso': '2025-11-30',
#   'startDateIso': '2025-11-03',
#   'hasReviewedDates': True,
#   'volume24hr': 506761.76677499944,
#   'volume1wk': 972515.0164049997,
#   'volume1mo': 989915.0164049997,
#   'volume1yr': 989915.0164049997,
#   'gameStartTime': '2025-11-30 20:30:00+00',
#   'secondsDelay': 3,
#   'clobTokenIds': '["85390311792024349404167851159763248867505632418323336298720378677183423835864", "62537372501669314673531905864560195112330691896349857297245896454067226511334"]',
#   'umaBond': '500',
#   'umaReward': '2',
#   'volume24hrClob': 506761.76677499944,
#   'volume1wkClob': 972515.0164049997,
#   'volume1moClob': 989915.0164049997,
#   'volume1yrClob': 989915.0164049997,
#   'volumeClob': 989915.016405,
#   'liquidityClob': 377915.04324,
#   'customLiveness': 0,
#   'acceptingOrders': True,
#   'negRisk': False,
#   'negRiskRequestID': '',
#   'events': [{'id': '72005',
#     'ticker': 'nhl-ana-chi-2025-11-30',
#     'slug': 'nhl-ana-chi-2025-11-30',
#     'title': 'Ducks vs. Blackhawks',
#     'description': 'In the upcoming NHL game, scheduled for November 30 at 10:30AM ET:\nIf the Ducks win, the market will resolve to "Ducks".\nIf the Blackhawks win, the market will resolve to "Blackhawks".\nIf the game is postponed, this market will remain open until the game has been completed.\nIf the game is canceled entirely, with no make-up game, this market will resolve 50-50.\nThe result will be determined based on the final score including any overtime periods and shootouts. In the event of a shootout, one goal will be added to the winning team\'s score for the purpose of resolution.',
#     'resolutionSource': 'https://www.nhl.com/scores',
#     'startDate': '2025-11-03T16:32:24.682479Z',
#     'creationDate': '2025-11-30T15:30:00Z',
#     'endDate': '2025-11-30T15:30:00Z',
#     'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#     'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#     'active': True,
#     'closed': False,
#     'archived': False,
#     'new': False,
#     'featured': False,
#     'restricted': True,
#     'liquidity': 525016.06496,
#     'volume': 1015835.735222,
#     'openInterest': 0,
#     'createdAt': '2025-11-03T16:30:17.205014Z',
#     'updatedAt': '2025-12-01T00:21:12.274972Z',
#     'competitive': 0.8003199679231757,
#     'volume24hr': 616756.6811329994,
#     'volume1wk': 618482.2491719993,
#     'volume1mo': 635882.2491719993,
#     'volume1yr': 635882.2491719993,
#     'enableOrderBook': True,
#     'liquidityClob': 525016.06496,
#     'negRisk': False,
#     'commentCount': 7,
#     'series': [{'id': '10346',
#       'ticker': 'nhl-2026',
#       'slug': 'nhl-2026',
#       'title': 'NHL 2026',
#       'seriesType': 'single',
#       'recurrence': 'daily',
#       'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#       'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#       'active': True,
#       'closed': False,
#       'archived': False,
#       'featured': False,
#       'restricted': True,
#       'createdAt': '2025-10-02T17:24:41.601549Z',
#       'updatedAt': '2025-12-01T00:21:36.186202Z',
#       'volume': 3557746.449572,
#       'liquidity': 1655526.99976,
#       'commentCount': 223361}],
#     'cyom': False,
#     'showAllOutcomes': True,
#     'showMarketImages': False,
#     'enableNegRisk': False,
#     'automaticallyActive': True,
#     'eventDate': '2025-11-30',
#     'startTime': '2025-11-30T20:30:00Z',
#     'eventWeek': 9,
#     'seriesSlug': 'nhl-2026',
#     'score': '3-5',
#     'elapsed': '',
#     'period': 'VFT',
#     'live': False,
#     'ended': True,
#     'finishedTimestamp': '2025-11-30T23:17:29.538591Z',
#     'negRiskAugmented': False,
#     'pendingDeployment': False,
#     'deploying': False,
#     'gameId': 30024376}],
#   'ready': False,
#   'funded': False,
#   'acceptingOrdersTimestamp': '2025-11-03T16:31:01Z',
#   'cyom': False,
#   'competitive': 0.8003199679231757,
#   'pagerDutyNotificationEnabled': False,
#   'approved': True,
#   'rewardsMinSize': 0,
#   'rewardsMaxSpread': 0,
#   'spread': 0.001,
#   'oneDayPriceChange': -0.025,
#   'oneHourPriceChange': -0.02,
#   'oneWeekPriceChange': 0.01,
#   'lastTradePrice': 0.01,
#   'bestAsk': 0.001,
#   'automaticallyActive': True,
#   'clearBookOnStart': True,
#   'manualActivation': False,
#   'negRiskOther': False,
#   'sportsMarketType': 'moneyline',
#   'umaResolutionStatuses': '["proposed"]',
#   'pendingDeployment': False,
#   'deploying': False,
#   'deployingTimestamp': '2025-11-03T16:30:29.550614Z',
#   'rfqEnabled': False,
#   'holdingRewardsEnabled': False,
#   'feesEnabled': False},
#  {'id': '662229',
#   'question': 'Flames vs. Hurricanes',
#   'conditionId': '0x1f68a2025a13564f024b0a2265a2f0388f702556f6dc3d9f7e418ca3a23c2e58',
#   'slug': 'nhl-cal-car-2025-11-30',
#   'resolutionSource': 'https://www.nhl.com/scores',
#   'endDate': '2025-11-30T17:00:00Z',
#   'liquidity': '9427.5925',
#   'startDate': '2025-11-03T16:31:24.390606Z',
#   'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#   'description': 'In the upcoming NHL game, scheduled for November 30 at 12:00PM ET:\nIf the Flames win, the market will resolve to "Flames".\nIf the Hurricanes win, the market will resolve to "Hurricanes".\nIf the game is postponed, this market will remain open until the game has been completed.\nIf the game is canceled entirely, with no make-up game, this market will resolve 50-50.\nThe result will be determined based on the final score including any overtime periods and shootouts. In the event of a shootout, one goal will be added to the winning team\'s score for the purpose of resolution.',
#   'outcomes': '["Flames", "Hurricanes"]',
#   'outcomePrices': '["0.405", "0.595"]',
#   'volume': '427857.115335',
#   'active': True,
#   'closed': False,
#   'marketMakerAddress': '',
#   'createdAt': '2025-11-03T16:30:17.575623Z',
#   'updatedAt': '2025-12-01T00:20:32.41034Z',
#   'new': False,
#   'featured': False,
#   'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5',
#   'archived': False,
#   'resolvedBy': '0x65070BE91477460D8A7AeEb94ef92fe056C2f2A7',
#   'restricted': True,
#   'groupItemThreshold': '0',
#   'questionID': '0xcb0816135658ce5d942c19ea23182ee55dbe48ec20e56457ef1eb5528e6aaa6b',
#   'enableOrderBook': True,
#   'orderPriceMinTickSize': 0.01,
#   'orderMinSize': 5,
#   'volumeNum': 427857.115335,
#   'liquidityNum': 9427.5925,
#   'endDateIso': '2025-11-30',
#   'startDateIso': '2025-11-03',
#   'hasReviewedDates': True,
#   'volume24hr': 241698.691787,
#   'volume1wk': 242652.11789,
#   'volume1mo': 243292.11789,
#   'volume1yr': 243292.11789,
#   'gameStartTime': '2025-11-30 22:00:00+00',
#   'secondsDelay': 3,
#   'clobTokenIds': '["4930677984690670558881756691379033912320114996571584553135600504442779541756", "114763026359250736599134591252266409472571829737312899458617441947221727975127"]',
#   'umaBond': '500',
#   'umaReward': '2',
#   'volume24hrClob': 241698.691787,
#   'volume1wkClob': 242652.11789,
#   'volume1moClob': 243292.11789,
#   'volume1yrClob': 243292.11789,
#   'volumeClob': 427857.115335,
#   'liquidityClob': 9427.5925,
#   'customLiveness': 0,
#   'acceptingOrders': True,
#   'negRisk': False,
#   'negRiskRequestID': '',
#   'events': [{'id': '72006',
#     'ticker': 'nhl-cal-car-2025-11-30',
#     'slug': 'nhl-cal-car-2025-11-30',
#     'title': 'Flames vs. Hurricanes',
#     'description': 'In the upcoming NHL game, scheduled for November 30 at 12:00PM ET:\nIf the Flames win, the market will resolve to "Flames".\nIf the Hurricanes win, the market will resolve to "Hurricanes".\nIf the game is postponed, this market will remain open until the game has been completed.\nIf the game is canceled entirely, with no make-up game, this market will resolve 50-50.\nThe result will be determined based on the final score including any overtime periods and shootouts. In the event of a shootout, one goal will be added to the winning team\'s score for the purpose of resolution.',
#     'resolutionSource': 'https://www.nhl.com/scores',
#     'startDate': '2025-11-03T16:32:24.686586Z',
#     'creationDate': '2025-11-30T17:00:00Z',
#     'endDate': '2025-11-30T17:00:00Z',
#     'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#     'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#     'active': True,
#     'closed': False,
#     'archived': False,
#     'new': False,
#     'featured': False,
#     'restricted': True,
#     'liquidity': 11069.6216,
#     'volume': 436497.344563,
#     'openInterest': 0,
#     'createdAt': '2025-11-03T16:30:17.571042Z',
#     'updatedAt': '2025-12-01T00:21:23.706662Z',
#     'competitive': 0.9910557221079755,
#     'volume24hr': 242458.182453,
#     'volume1wk': 243411.608556,
#     'volume1mo': 244051.608556,
#     'volume1yr': 244051.608556,
#     'enableOrderBook': True,
#     'liquidityClob': 11069.6216,
#     'negRisk': False,
#     'commentCount': 7,
#     'series': [{'id': '10346',
#       'ticker': 'nhl-2026',
#       'slug': 'nhl-2026',
#       'title': 'NHL 2026',
#       'seriesType': 'single',
#       'recurrence': 'daily',
#       'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#       'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#       'active': True,
#       'closed': False,
#       'archived': False,
#       'featured': False,
#       'restricted': True,
#       'createdAt': '2025-10-02T17:24:41.601549Z',
#       'updatedAt': '2025-12-01T00:21:36.186202Z',
#       'volume': 3557746.449572,
#       'liquidity': 1655526.99976,
#       'commentCount': 223361}],
#     'cyom': False,
#     'showAllOutcomes': True,
#     'showMarketImages': False,
#     'enableNegRisk': False,
#     'automaticallyActive': True,
#     'eventDate': '2025-11-30',
#     'startTime': '2025-11-30T22:00:00Z',
#     'eventWeek': 9,
#     'seriesSlug': 'nhl-2026',
#     'score': '0-0',
#     'elapsed': '',
#     'period': 'End P3',
#     'live': True,
#     'ended': False,
#     'negRiskAugmented': False,
#     'pendingDeployment': False,
#     'deploying': False,
#     'gameId': 30024377}],
#   'ready': False,
#   'funded': False,
#   'acceptingOrdersTimestamp': '2025-11-03T16:31:03Z',
#   'cyom': False,
#   'competitive': 0.9910557221079755,
#   'pagerDutyNotificationEnabled': False,
#   'approved': True,
#   'rewardsMinSize': 0,
#   'rewardsMaxSpread': 0,
#   'spread': 0.01,
#   'oneDayPriceChange': -0.01,
#   'oneWeekPriceChange': 0.015,
#   'lastTradePrice': 0.41,
#   'bestBid': 0.4,
#   'bestAsk': 0.41,
#   'automaticallyActive': True,
#   'clearBookOnStart': True,
#   'manualActivation': False,
#   'negRiskOther': False,
#   'sportsMarketType': 'moneyline',
#   'umaResolutionStatuses': '[]',
#   'pendingDeployment': False,
#   'deploying': False,
#   'deployingTimestamp': '2025-11-03T16:30:29.552796Z',
#   'rfqEnabled': False,
#   'holdingRewardsEnabled': False,
#   'feesEnabled': False},
#  {'id': '662230',
#   'question': 'Senators vs. Stars',
#   'conditionId': '0xcc7a1b21a5cdd2eb10014ffd0b0e0fd258c088e59b3b900652a2aa33ba6b22c9',
#   'slug': 'nhl-ott-dal-2025-11-30',
#   'resolutionSource': 'https://www.nhl.com/scores',
#   'endDate': '2025-11-30T18:00:00Z',
#   'liquidity': '20377.8596',
#   'startDate': '2025-11-03T16:31:24.646311Z',
#   'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#   'description': 'In the upcoming NHL game, scheduled for November 30 at 1:00PM ET:\nIf the Senators win, the market will resolve to "Senators".\nIf the Stars win, the market will resolve to "Stars".\nIf the game is postponed, this market will remain open until the game has been completed.\nIf the game is canceled entirely, with no make-up game, this market will resolve 50-50.\nThe result will be determined based on the final score including any overtime periods and shootouts. In the event of a shootout, one goal will be added to the winning team\'s score for the purpose of resolution.',
#   'outcomes': '["Senators", "Stars"]',
#   'outcomePrices': '["0.265", "0.735"]',
#   'volume': '670896.536036',
#   'active': True,
#   'closed': False,
#   'marketMakerAddress': '',
#   'createdAt': '2025-11-03T16:30:17.942402Z',
#   'updatedAt': '2025-12-01T00:23:21.542247Z',
#   'new': False,
#   'featured': False,
#   'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5',
#   'archived': False,
#   'resolvedBy': '0x65070BE91477460D8A7AeEb94ef92fe056C2f2A7',
#   'restricted': True,
#   'groupItemThreshold': '0',
#   'questionID': '0x90ceed9bdf18205f73e0f3621a836a40d8b16f45ef4eb3a7594ce93494809ee3',
#   'enableOrderBook': True,
#   'orderPriceMinTickSize': 0.01,
#   'orderMinSize': 5,
#   'volumeNum': 670896.536036,
#   'liquidityNum': 20377.8596,
#   'endDateIso': '2025-11-30',
#   'startDateIso': '2025-11-03',
#   'hasReviewedDates': True,
#   'volume24hr': 640427.5019240002,
#   'volume1wk': 643796.5826210002,
#   'volume1mo': 665861.5826210002,
#   'volume1yr': 665861.5826210002,
#   'gameStartTime': '2025-11-30 23:00:00+00',
#   'secondsDelay': 3,
#   'clobTokenIds': '["31174778001349657703924529229973351018576722835451577198626475177238545112468", "105386948240362199755685711537714600230625876215750758110391376911328226915497"]',
#   'umaBond': '500',
#   'umaReward': '2',
#   'volume24hrClob': 640427.5019240002,
#   'volume1wkClob': 643796.5826210002,
#   'volume1moClob': 665861.5826210002,
#   'volume1yrClob': 665861.5826210002,
#   'volumeClob': 670896.536036,
#   'liquidityClob': 20377.8596,
#   'customLiveness': 0,
#   'acceptingOrders': True,
#   'negRisk': False,
#   'negRiskRequestID': '',
#   'events': [{'id': '72007',
#     'ticker': 'nhl-ott-dal-2025-11-30',
#     'slug': 'nhl-ott-dal-2025-11-30',
#     'title': 'Senators vs. Stars',
#     'description': 'In the upcoming NHL game, scheduled for November 30 at 1:00PM ET:\nIf the Senators win, the market will resolve to "Senators".\nIf the Stars win, the market will resolve to "Stars".\nIf the game is postponed, this market will remain open until the game has been completed.\nIf the game is canceled entirely, with no make-up game, this market will resolve 50-50.\nThe result will be determined based on the final score including any overtime periods and shootouts. In the event of a shootout, one goal will be added to the winning team\'s score for the purpose of resolution.',
#     'resolutionSource': 'https://www.nhl.com/scores',
#     'startDate': '2025-11-03T16:32:24.688546Z',
#     'creationDate': '2025-11-30T18:00:00Z',
#     'endDate': '2025-11-30T18:00:00Z',
#     'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#     'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#     'active': True,
#     'closed': False,
#     'archived': False,
#     'new': False,
#     'featured': False,
#     'restricted': True,
#     'liquidity': 17094.431,
#     'volume': 674342.055006,
#     'openInterest': 0,
#     'createdAt': '2025-11-03T16:30:17.92375Z',
#     'updatedAt': '2025-12-01T00:21:23.642677Z',
#     'competitive': 0.9518143961927424,
#     'volume24hr': 86598.57113999999,
#     'volume1wk': 87652.74957600002,
#     'volume1mo': 109717.7495759999,
#     'volume1yr': 109717.7495759999,
#     'enableOrderBook': True,
#     'liquidityClob': 17094.431,
#     'negRisk': False,
#     'commentCount': 7,
#     'series': [{'id': '10346',
#       'ticker': 'nhl-2026',
#       'slug': 'nhl-2026',
#       'title': 'NHL 2026',
#       'seriesType': 'single',
#       'recurrence': 'daily',
#       'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#       'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#       'active': True,
#       'closed': False,
#       'archived': False,
#       'featured': False,
#       'restricted': True,
#       'createdAt': '2025-10-02T17:24:41.601549Z',
#       'updatedAt': '2025-12-01T00:21:36.186202Z',
#       'volume': 3557746.449572,
#       'liquidity': 1655526.99976,
#       'commentCount': 223361}],
#     'cyom': False,
#     'showAllOutcomes': True,
#     'showMarketImages': False,
#     'enableNegRisk': False,
#     'automaticallyActive': True,
#     'eventDate': '2025-11-30',
#     'startTime': '2025-11-30T23:00:00Z',
#     'eventWeek': 9,
#     'seriesSlug': 'nhl-2026',
#     'score': '1-2',
#     'elapsed': '7',
#     'period': 'P2',
#     'live': True,
#     'ended': False,
#     'negRiskAugmented': False,
#     'pendingDeployment': False,
#     'deploying': False,
#     'gameId': 30024378}],
#   'ready': False,
#   'funded': False,
#   'acceptingOrdersTimestamp': '2025-11-03T16:31:03Z',
#   'cyom': False,
#   'competitive': 0.9476651898884124,
#   'pagerDutyNotificationEnabled': False,
#   'approved': True,
#   'rewardsMinSize': 0,
#   'rewardsMaxSpread': 0,
#   'spread': 0.01,
#   'oneDayPriceChange': 0.01,
#   'oneWeekPriceChange': -0.03,
#   'lastTradePrice': 0.25,
#   'bestBid': 0.26,
#   'bestAsk': 0.27,
#   'automaticallyActive': True,
#   'clearBookOnStart': True,
#   'manualActivation': False,
#   'negRiskOther': False,
#   'sportsMarketType': 'moneyline',
#   'umaResolutionStatuses': '[]',
#   'pendingDeployment': False,
#   'deploying': False,
#   'deployingTimestamp': '2025-11-03T16:30:29.554934Z',
#   'rfqEnabled': False,
#   'holdingRewardsEnabled': False,
#   'feesEnabled': False},
#  {'id': '665093',
#   'question': 'Penguins vs. Flyers',
#   'conditionId': '0x2e3b029ceb8e1c0c4d09c1178582beda70f6d1ed118c6a9b5e4d2071578ff936',
#   'slug': 'nhl-pit-phi-2025-12-01',
#   'resolutionSource': 'https://www.nhl.com/scores',
#   'endDate': '2025-12-01T19:00:00Z',
#   'liquidity': '49341.6674',
#   'startDate': '2025-11-04T16:31:06.603478Z',
#   'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#   'description': 'In the upcoming NHL game, scheduled for December 1 at 2:00PM ET:\nIf the Penguins win, the market will resolve to "Penguins".\nIf the Flyers win, the market will resolve to "Flyers".\nIf the game is postponed, this market will remain open until the game has been completed.\nIf the game is canceled entirely, with no make-up game, this market will resolve 50-50.\nThe result will be determined based on the final score including any overtime periods and shootouts. In the event of a shootout, one goal will be added to the winning team\'s score for the purpose of resolution.',
#   'outcomes': '["Penguins", "Flyers"]',
#   'outcomePrices': '["0.43", "0.57"]',
#   'volume': '123023.430098',
#   'active': True,
#   'closed': False,
#   'marketMakerAddress': '',
#   'createdAt': '2025-11-04T16:30:13.968654Z',
#   'updatedAt': '2025-12-01T00:27:49.736773Z',
#   'new': False,
#   'featured': False,
#   'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5',
#   'archived': False,
#   'resolvedBy': '0x65070BE91477460D8A7AeEb94ef92fe056C2f2A7',
#   'restricted': True,
#   'groupItemThreshold': '0',
#   'questionID': '0xf5844ac52b50f16ec4bd63b7462e3c37ecb7c623e56a08218aaa98d6df4305d0',
#   'enableOrderBook': True,
#   'orderPriceMinTickSize': 0.01,
#   'orderMinSize': 5,
#   'volumeNum': 123023.430098,
#   'liquidityNum': 49341.6674,
#   'endDateIso': '2025-12-01',
#   'startDateIso': '2025-11-04',
#   'hasReviewedDates': True,
#   'volume24hr': 122967.305526,
#   'volume1wk': 123023.430098,
#   'volume1mo': 123023.430098,
#   'volume1yr': 123023.430098,
#   'gameStartTime': '2025-12-02 00:00:00+00',
#   'secondsDelay': 3,
#   'clobTokenIds': '["76445843001326438833133810268768412704033159020527963211264239205376387267153", "23603588475354724440054467487699158886701351034547889588607395819623124794692"]',
#   'umaBond': '500',
#   'umaReward': '2',
#   'volume24hrClob': 122967.305526,
#   'volume1wkClob': 123023.430098,
#   'volume1moClob': 123023.430098,
#   'volume1yrClob': 123023.430098,
#   'volumeClob': 123023.430098,
#   'liquidityClob': 49341.6674,
#   'customLiveness': 0,
#   'acceptingOrders': True,
#   'negRisk': False,
#   'negRiskRequestID': '',
#   'events': [{'id': '72985',
#     'ticker': 'nhl-pit-phi-2025-12-01',
#     'slug': 'nhl-pit-phi-2025-12-01',
#     'title': 'Penguins vs. Flyers',
#     'description': 'In the upcoming NHL game, scheduled for December 1 at 2:00PM ET:\nIf the Penguins win, the market will resolve to "Penguins".\nIf the Flyers win, the market will resolve to "Flyers".\nIf the game is postponed, this market will remain open until the game has been completed.\nIf the game is canceled entirely, with no make-up game, this market will resolve 50-50.\nThe result will be determined based on the final score including any overtime periods and shootouts. In the event of a shootout, one goal will be added to the winning team\'s score for the purpose of resolution.',
#     'resolutionSource': 'https://www.nhl.com/scores',
#     'startDate': '2025-11-04T16:40:34.393625Z',
#     'creationDate': '2025-12-01T19:00:00Z',
#     'endDate': '2025-12-01T19:00:00Z',
#     'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#     'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#     'active': True,
#     'closed': False,
#     'archived': False,
#     'new': False,
#     'featured': False,
#     'restricted': True,
#     'liquidity': 61859.305,
#     'volume': 123461.269094,
#     'openInterest': 0,
#     'createdAt': '2025-11-04T16:30:13.963894Z',
#     'updatedAt': '2025-12-01T00:21:14.946623Z',
#     'competitive': 0.9979790923380155,
#     'volume24hr': 114959.044011,
#     'volume1wk': 114988.168583,
#     'volume1mo': 114988.168583,
#     'volume1yr': 114988.168583,
#     'enableOrderBook': True,
#     'liquidityClob': 61859.305,
#     'negRisk': False,
#     'commentCount': 5,
#     'series': [{'id': '10346',
#       'ticker': 'nhl-2026',
#       'slug': 'nhl-2026',
#       'title': 'NHL 2026',
#       'seriesType': 'single',
#       'recurrence': 'daily',
#       'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#       'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#       'active': True,
#       'closed': False,
#       'archived': False,
#       'featured': False,
#       'restricted': True,
#       'createdAt': '2025-10-02T17:24:41.601549Z',
#       'updatedAt': '2025-12-01T00:21:36.186202Z',
#       'volume': 3557746.449572,
#       'liquidity': 1655526.99976,
#       'commentCount': 223361}],
#     'cyom': False,
#     'showAllOutcomes': True,
#     'showMarketImages': False,
#     'enableNegRisk': False,
#     'automaticallyActive': True,
#     'eventDate': '2025-12-01',
#     'startTime': '2025-12-02T00:00:00Z',
#     'eventWeek': 9,
#     'seriesSlug': 'nhl-2026',
#     'negRiskAugmented': False,
#     'pendingDeployment': False,
#     'deploying': False,
#     'gameId': 30024379}],
#   'ready': False,
#   'funded': False,
#   'acceptingOrdersTimestamp': '2025-11-04T16:30:45Z',
#   'cyom': False,
#   'competitive': 0.9951238929246691,
#   'pagerDutyNotificationEnabled': False,
#   'approved': True,
#   'rewardsMinSize': 0,
#   'rewardsMaxSpread': 0,
#   'spread': 0.02,
#   'oneDayPriceChange': -0.07,
#   'oneWeekPriceChange': -0.08,
#   'lastTradePrice': 0.44,
#   'bestBid': 0.42,
#   'bestAsk': 0.44,
#   'automaticallyActive': True,
#   'clearBookOnStart': True,
#   'manualActivation': False,
#   'negRiskOther': False,
#   'sportsMarketType': 'moneyline',
#   'umaResolutionStatuses': '[]',
#   'pendingDeployment': False,
#   'deploying': False,
#   'deployingTimestamp': '2025-11-04T16:30:16.751699Z',
#   'rfqEnabled': False,
#   'holdingRewardsEnabled': False,
#   'feesEnabled': False},
#  {'id': '665094',
#   'question': 'Blue Jackets vs. Devils',
#   'conditionId': '0xe0aa6b8e4eb3389e349f5c898b35c5295b5a31ecea91fc2f9d35aa4a1d580ea2',
#   'slug': 'nhl-cbj-nj-2025-12-01',
#   'resolutionSource': 'https://www.nhl.com/scores',
#   'endDate': '2025-12-01T19:00:00Z',
#   'liquidity': '51565.4719',
#   'startDate': '2025-11-04T16:31:09.143537Z',
#   'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#   'description': 'In the upcoming NHL game, scheduled for December 1 at 2:00PM ET:\nIf the Blue Jackets win, the market will resolve to "Blue Jackets".\nIf the Devils win, the market will resolve to "Devils".\nIf the game is postponed, this market will remain open until the game has been completed.\nIf the game is canceled entirely, with no make-up game, this market will resolve 50-50.\nThe result will be determined based on the final score including any overtime periods and shootouts. In the event of a shootout, one goal will be added to the winning team\'s score for the purpose of resolution.',
#   'outcomes': '["Blue Jackets", "Devils"]',
#   'outcomePrices': '["0.415", "0.585"]',
#   'volume': '174681.404129',
#   'active': True,
#   'closed': False,
#   'marketMakerAddress': '',
#   'createdAt': '2025-11-04T16:30:14.298011Z',
#   'updatedAt': '2025-12-01T00:20:26.852735Z',
#   'new': False,
#   'featured': False,
#   'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5',
#   'archived': False,
#   'resolvedBy': '0x65070BE91477460D8A7AeEb94ef92fe056C2f2A7',
#   'restricted': True,
#   'groupItemThreshold': '0',
#   'questionID': '0xf73ff73c8b72db0a640667b1c7f956fb1d7cfdd0250bcd3a73db0f4522f83dcd',
#   'enableOrderBook': True,
#   'orderPriceMinTickSize': 0.01,
#   'orderMinSize': 5,
#   'volumeNum': 174681.404129,
#   'liquidityNum': 51565.4719,
#   'endDateIso': '2025-12-01',
#   'startDateIso': '2025-11-04',
#   'hasReviewedDates': True,
#   'volume24hr': 170452.80785600003,
#   'volume1wk': 170540.628881,
#   'volume1mo': 170540.628881,
#   'volume1yr': 170540.628881,
#   'gameStartTime': '2025-12-02 00:00:00+00',
#   'secondsDelay': 3,
#   'clobTokenIds': '["62713045668567434715644346451932098658617866033975395249877881152638949907126", "102950284613835345612643524429541260146836688491515303295730454074436742133575"]',
#   'umaBond': '500',
#   'umaReward': '2',
#   'volume24hrClob': 170452.80785600003,
#   'volume1wkClob': 170540.628881,
#   'volume1moClob': 170540.628881,
#   'volume1yrClob': 170540.628881,
#   'volumeClob': 174681.404129,
#   'liquidityClob': 51565.4719,
#   'customLiveness': 0,
#   'acceptingOrders': True,
#   'negRisk': False,
#   'negRiskRequestID': '',
#   'events': [{'id': '72986',
#     'ticker': 'nhl-cbj-nj-2025-12-01',
#     'slug': 'nhl-cbj-nj-2025-12-01',
#     'title': 'Blue Jackets vs. Devils',
#     'description': 'In the upcoming NHL game, scheduled for December 1 at 2:00PM ET:\nIf the Blue Jackets win, the market will resolve to "Blue Jackets".\nIf the Devils win, the market will resolve to "Devils".\nIf the game is postponed, this market will remain open until the game has been completed.\nIf the game is canceled entirely, with no make-up game, this market will resolve 50-50.\nThe result will be determined based on the final score including any overtime periods and shootouts. In the event of a shootout, one goal will be added to the winning team\'s score for the purpose of resolution.',
#     'resolutionSource': 'https://www.nhl.com/scores',
#     'startDate': '2025-11-04T16:40:34.397739Z',
#     'creationDate': '2025-12-01T19:00:00Z',
#     'endDate': '2025-12-01T19:00:00Z',
#     'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#     'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#     'active': True,
#     'closed': False,
#     'archived': False,
#     'new': False,
#     'featured': False,
#     'restricted': True,
#     'liquidity': 63417.5699,
#     'volume': 175074.253281,
#     'openInterest': 0,
#     'createdAt': '2025-11-04T16:30:14.294123Z',
#     'updatedAt': '2025-12-01T00:21:23.181711Z',
#     'competitive': 0.9969841230278408,
#     'volume24hr': 170452.80785600003,
#     'volume1wk': 170540.628881,
#     'volume1mo': 170540.628881,
#     'volume1yr': 170540.628881,
#     'enableOrderBook': True,
#     'liquidityClob': 63417.5699,
#     'negRisk': False,
#     'commentCount': 5,
#     'series': [{'id': '10346',
#       'ticker': 'nhl-2026',
#       'slug': 'nhl-2026',
#       'title': 'NHL 2026',
#       'seriesType': 'single',
#       'recurrence': 'daily',
#       'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#       'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#       'active': True,
#       'closed': False,
#       'archived': False,
#       'featured': False,
#       'restricted': True,
#       'createdAt': '2025-10-02T17:24:41.601549Z',
#       'updatedAt': '2025-12-01T00:21:36.186202Z',
#       'volume': 3557746.449572,
#       'liquidity': 1655526.99976,
#       'commentCount': 223361}],
#     'cyom': False,
#     'showAllOutcomes': True,
#     'showMarketImages': False,
#     'enableNegRisk': False,
#     'automaticallyActive': True,
#     'eventDate': '2025-12-01',
#     'startTime': '2025-12-02T00:00:00Z',
#     'eventWeek': 9,
#     'seriesSlug': 'nhl-2026',
#     'negRiskAugmented': False,
#     'pendingDeployment': False,
#     'deploying': False,
#     'gameId': 30024380}],
#   'ready': False,
#   'funded': False,
#   'acceptingOrdersTimestamp': '2025-11-04T16:30:47Z',
#   'cyom': False,
#   'competitive': 0.9928268261808434,
#   'pagerDutyNotificationEnabled': False,
#   'approved': True,
#   'rewardsMinSize': 0,
#   'rewardsMaxSpread': 0,
#   'spread': 0.01,
#   'oneDayPriceChange': -0.01,
#   'oneHourPriceChange': 0.005,
#   'oneWeekPriceChange': -0.04,
#   'lastTradePrice': 0.42,
#   'bestBid': 0.41,
#   'bestAsk': 0.42,
#   'automaticallyActive': True,
#   'clearBookOnStart': True,
#   'manualActivation': False,
#   'negRiskOther': False,
#   'sportsMarketType': 'moneyline',
#   'umaResolutionStatuses': '[]',
#   'pendingDeployment': False,
#   'deploying': False,
#   'deployingTimestamp': '2025-11-04T16:30:16.753509Z',
#   'rfqEnabled': False,
#   'holdingRewardsEnabled': False,
#   'feesEnabled': False},
#  {'id': '665095',
#   'question': 'Jets vs. Sabres',
#   'conditionId': '0x94e5755f637eef9c6641d32183f4ef7d2d316cd6908e6c21476b8245744c1cae',
#   'slug': 'nhl-wpg-buf-2025-12-01',
#   'resolutionSource': 'https://www.nhl.com/scores',
#   'endDate': '2025-12-01T19:30:00Z',
#   'liquidity': '48569.0125',
#   'startDate': '2025-11-04T16:31:09.401209Z',
#   'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#   'description': 'In the upcoming NHL game, scheduled for December 1 at 2:30PM ET:\nIf the Jets win, the market will resolve to "Jets".\nIf the Sabres win, the market will resolve to "Sabres".\nIf the game is postponed, this market will remain open until the game has been completed.\nIf the game is canceled entirely, with no make-up game, this market will resolve 50-50.\nThe result will be determined based on the final score including any overtime periods and shootouts. In the event of a shootout, one goal will be added to the winning team\'s score for the purpose of resolution.',
#   'outcomes': '["Jets", "Sabres"]',
#   'outcomePrices': '["0.495", "0.505"]',
#   'volume': '907.349958',
#   'active': True,
#   'closed': False,
#   'marketMakerAddress': '',
#   'createdAt': '2025-11-04T16:30:14.617632Z',
#   'updatedAt': '2025-12-01T00:20:12.628582Z',
#   'new': False,
#   'featured': False,
#   'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5',
#   'archived': False,
#   'resolvedBy': '0x65070BE91477460D8A7AeEb94ef92fe056C2f2A7',
#   'restricted': True,
#   'groupItemThreshold': '0',
#   'questionID': '0x0a7b79556cafa4fd89bd45f2c362ec7f5b73b2d20e59226a8e98ca2820ab058b',
#   'enableOrderBook': True,
#   'orderPriceMinTickSize': 0.01,
#   'orderMinSize': 5,
#   'volumeNum': 907.349958,
#   'liquidityNum': 48569.0125,
#   'endDateIso': '2025-12-01',
#   'startDateIso': '2025-11-04',
#   'hasReviewedDates': True,
#   'volume24hr': 495.201357,
#   'volume1wk': 580.5217260000001,
#   'volume1mo': 580.5217260000001,
#   'volume1yr': 580.5217260000001,
#   'gameStartTime': '2025-12-02 00:30:00+00',
#   'secondsDelay': 3,
#   'clobTokenIds': '["35853292942112225608356243737927553175068462960382577845869775379652435705879", "98633723122075100615635689681614790537400998599814509890499551543177469795624"]',
#   'umaBond': '500',
#   'umaReward': '2',
#   'volume24hrClob': 495.201357,
#   'volume1wkClob': 580.5217260000001,
#   'volume1moClob': 580.5217260000001,
#   'volume1yrClob': 580.5217260000001,
#   'volumeClob': 907.349958,
#   'liquidityClob': 48569.0125,
#   'customLiveness': 0,
#   'acceptingOrders': True,
#   'negRisk': False,
#   'negRiskRequestID': '',
#   'events': [{'id': '72987',
#     'ticker': 'nhl-wpg-buf-2025-12-01',
#     'slug': 'nhl-wpg-buf-2025-12-01',
#     'title': 'Jets vs. Sabres',
#     'description': 'In the upcoming NHL game, scheduled for December 1 at 2:30PM ET:\nIf the Jets win, the market will resolve to "Jets".\nIf the Sabres win, the market will resolve to "Sabres".\nIf the game is postponed, this market will remain open until the game has been completed.\nIf the game is canceled entirely, with no make-up game, this market will resolve 50-50.\nThe result will be determined based on the final score including any overtime periods and shootouts. In the event of a shootout, one goal will be added to the winning team\'s score for the purpose of resolution.',
#     'resolutionSource': 'https://www.nhl.com/scores',
#     'startDate': '2025-11-04T16:40:34.400999Z',
#     'creationDate': '2025-12-01T19:30:00Z',
#     'endDate': '2025-12-01T19:30:00Z',
#     'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#     'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#     'active': True,
#     'closed': False,
#     'archived': False,
#     'new': False,
#     'featured': False,
#     'restricted': True,
#     'liquidity': 60234.9982,
#     'volume': 1673.150287,
#     'openInterest': 0,
#     'createdAt': '2025-11-04T16:30:14.613699Z',
#     'updatedAt': '2025-12-01T00:21:15.112511Z',
#     'competitive': 0.9999750006249843,
#     'volume24hr': 495.201357,
#     'volume1wk': 580.5217260000001,
#     'volume1mo': 580.5217260000001,
#     'volume1yr': 580.5217260000001,
#     'enableOrderBook': True,
#     'liquidityClob': 60234.9982,
#     'negRisk': False,
#     'commentCount': 5,
#     'series': [{'id': '10346',
#       'ticker': 'nhl-2026',
#       'slug': 'nhl-2026',
#       'title': 'NHL 2026',
#       'seriesType': 'single',
#       'recurrence': 'daily',
#       'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#       'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#       'active': True,
#       'closed': False,
#       'archived': False,
#       'featured': False,
#       'restricted': True,
#       'createdAt': '2025-10-02T17:24:41.601549Z',
#       'updatedAt': '2025-12-01T00:21:36.186202Z',
#       'volume': 3557746.449572,
#       'liquidity': 1655526.99976,
#       'commentCount': 223361}],
#     'cyom': False,
#     'showAllOutcomes': True,
#     'showMarketImages': False,
#     'enableNegRisk': False,
#     'automaticallyActive': True,
#     'eventDate': '2025-12-01',
#     'startTime': '2025-12-02T00:30:00Z',
#     'eventWeek': 9,
#     'seriesSlug': 'nhl-2026',
#     'negRiskAugmented': False,
#     'pendingDeployment': False,
#     'deploying': False,
#     'gameId': 30024381}],
#   'ready': False,
#   'funded': False,
#   'acceptingOrdersTimestamp': '2025-11-04T16:30:47Z',
#   'cyom': False,
#   'competitive': 0.9999750006249843,
#   'pagerDutyNotificationEnabled': False,
#   'approved': True,
#   'rewardsMinSize': 0,
#   'rewardsMaxSpread': 0,
#   'spread': 0.01,
#   'oneDayPriceChange': -0.06,
#   'oneWeekPriceChange': -0.13,
#   'lastTradePrice': 0.5,
#   'bestBid': 0.49,
#   'bestAsk': 0.5,
#   'automaticallyActive': True,
#   'clearBookOnStart': True,
#   'manualActivation': False,
#   'negRiskOther': False,
#   'sportsMarketType': 'moneyline',
#   'umaResolutionStatuses': '[]',
#   'pendingDeployment': False,
#   'deploying': False,
#   'deployingTimestamp': '2025-11-04T16:30:16.762923Z',
#   'rfqEnabled': False,
#   'holdingRewardsEnabled': False,
#   'feesEnabled': False},
#  {'id': '665096',
#   'question': 'Ducks vs. Blues',
#   'conditionId': '0x361f0db81be273d7c6e13085abe47808d8f4b0f27e8f4df8a776049d863bfce2',
#   'slug': 'nhl-ana-stl-2025-12-01',
#   'resolutionSource': 'https://www.nhl.com/scores',
#   'endDate': '2025-12-01T20:00:00Z',
#   'liquidity': '43146.2355',
#   'startDate': '2025-11-04T16:31:08.629944Z',
#   'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#   'description': 'In the upcoming NHL game, scheduled for December 1 at 3:00PM ET:\nIf the Ducks win, the market will resolve to "Ducks".\nIf the Blues win, the market will resolve to "Blues".\nIf the game is postponed, this market will remain open until the game has been completed.\nIf the game is canceled entirely, with no make-up game, this market will resolve 50-50.\nThe result will be determined based on the final score including any overtime periods and shootouts. In the event of a shootout, one goal will be added to the winning team\'s score for the purpose of resolution.',
#   'outcomes': '["Ducks", "Blues"]',
#   'outcomePrices': '["0.415", "0.585"]',
#   'volume': '82944.319483',
#   'active': True,
#   'closed': False,
#   'marketMakerAddress': '',
#   'createdAt': '2025-11-04T16:30:14.93901Z',
#   'updatedAt': '2025-12-01T00:26:24.292527Z',
#   'new': False,
#   'featured': False,
#   'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5',
#   'archived': False,
#   'resolvedBy': '0x65070BE91477460D8A7AeEb94ef92fe056C2f2A7',
#   'restricted': True,
#   'groupItemThreshold': '0',
#   'questionID': '0x1219a617d456ab3f004858ea2a7d51ef5d07312b4f42ce68405e6ef6f2ef1075',
#   'enableOrderBook': True,
#   'orderPriceMinTickSize': 0.01,
#   'orderMinSize': 5,
#   'volumeNum': 82944.319483,
#   'liquidityNum': 43146.2355,
#   'endDateIso': '2025-12-01',
#   'startDateIso': '2025-11-04',
#   'hasReviewedDates': True,
#   'volume24hr': 82229.00244,
#   'volume1wk': 82704.49947599998,
#   'volume1mo': 82704.49947599998,
#   'volume1yr': 82704.49947599998,
#   'gameStartTime': '2025-12-02 01:00:00+00',
#   'secondsDelay': 3,
#   'clobTokenIds': '["87566824274626011600804324591729264555358980709220346418374643724944146806244", "92361025472332229382322786228989373369396519247069514433717908559586093728894"]',
#   'umaBond': '500',
#   'umaReward': '2',
#   'volume24hrClob': 82229.00244,
#   'volume1wkClob': 82704.49947599998,
#   'volume1moClob': 82704.49947599998,
#   'volume1yrClob': 82704.49947599998,
#   'volumeClob': 82944.319483,
#   'liquidityClob': 43146.2355,
#   'customLiveness': 0,
#   'acceptingOrders': True,
#   'negRisk': False,
#   'negRiskRequestID': '',
#   'events': [{'id': '72988',
#     'ticker': 'nhl-ana-stl-2025-12-01',
#     'slug': 'nhl-ana-stl-2025-12-01',
#     'title': 'Ducks vs. Blues',
#     'description': 'In the upcoming NHL game, scheduled for December 1 at 3:00PM ET:\nIf the Ducks win, the market will resolve to "Ducks".\nIf the Blues win, the market will resolve to "Blues".\nIf the game is postponed, this market will remain open until the game has been completed.\nIf the game is canceled entirely, with no make-up game, this market will resolve 50-50.\nThe result will be determined based on the final score including any overtime periods and shootouts. In the event of a shootout, one goal will be added to the winning team\'s score for the purpose of resolution.',
#     'resolutionSource': 'https://www.nhl.com/scores',
#     'startDate': '2025-11-04T16:40:25.356469Z',
#     'creationDate': '2025-12-01T20:00:00Z',
#     'endDate': '2025-12-01T20:00:00Z',
#     'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#     'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#     'active': True,
#     'closed': False,
#     'archived': False,
#     'new': False,
#     'featured': False,
#     'restricted': True,
#     'liquidity': 61070.7224,
#     'volume': 82773.022628,
#     'openInterest': 0,
#     'createdAt': '2025-11-04T16:30:14.934998Z',
#     'updatedAt': '2025-12-01T00:21:26.429003Z',
#     'competitive': 0.9979790923380155,
#     'volume24hr': 77061.236255,
#     'volume1wk': 77186.759407,
#     'volume1mo': 77186.759407,
#     'volume1yr': 77186.759407,
#     'enableOrderBook': True,
#     'liquidityClob': 61070.7224,
#     'negRisk': False,
#     'commentCount': 5,
#     'series': [{'id': '10346',
#       'ticker': 'nhl-2026',
#       'slug': 'nhl-2026',
#       'title': 'NHL 2026',
#       'seriesType': 'single',
#       'recurrence': 'daily',
#       'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#       'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#       'active': True,
#       'closed': False,
#       'archived': False,
#       'featured': False,
#       'restricted': True,
#       'createdAt': '2025-10-02T17:24:41.601549Z',
#       'updatedAt': '2025-12-01T00:21:36.186202Z',
#       'volume': 3557746.449572,
#       'liquidity': 1655526.99976,
#       'commentCount': 223361}],
#     'cyom': False,
#     'showAllOutcomes': True,
#     'showMarketImages': False,
#     'enableNegRisk': False,
#     'automaticallyActive': True,
#     'eventDate': '2025-12-01',
#     'startTime': '2025-12-02T01:00:00Z',
#     'eventWeek': 9,
#     'seriesSlug': 'nhl-2026',
#     'negRiskAugmented': False,
#     'pendingDeployment': False,
#     'deploying': False,
#     'gameId': 30024382}],
#   'ready': False,
#   'funded': False,
#   'acceptingOrdersTimestamp': '2025-11-04T16:30:47Z',
#   'cyom': False,
#   'competitive': 0.9928268261808434,
#   'pagerDutyNotificationEnabled': False,
#   'approved': True,
#   'rewardsMinSize': 0,
#   'rewardsMaxSpread': 0,
#   'spread': 0.01,
#   'oneDayPriceChange': -0.045,
#   'oneWeekPriceChange': -0.065,
#   'lastTradePrice': 0.42,
#   'bestBid': 0.41,
#   'bestAsk': 0.42,
#   'automaticallyActive': True,
#   'clearBookOnStart': True,
#   'manualActivation': False,
#   'negRiskOther': False,
#   'sportsMarketType': 'moneyline',
#   'umaResolutionStatuses': '[]',
#   'pendingDeployment': False,
#   'deploying': False,
#   'deployingTimestamp': '2025-11-04T16:30:16.761547Z',
#   'rfqEnabled': False,
#   'holdingRewardsEnabled': False,
#   'feesEnabled': False},
#  {'id': '665097',
#   'question': 'Utah vs. Sharks',
#   'conditionId': '0x1865de747937a0a66b9194923de4d7f2dc27555ba69fcd67d8a0055958c34b57',
#   'slug': 'nhl-utah-sj-2025-12-01',
#   'resolutionSource': 'https://www.nhl.com/scores',
# ...
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#   'description': 'In the upcoming NHL game, scheduled for December 27 at 10:00PM ET:\nIf the Avalanche win, the market will resolve to "Avalanche".\nIf the Golden Knights win, the market will resolve to "Golden Knights".\nIf the game is postponed, this market will remain open until the game has been completed.\nIf the game is canceled entirely, with no make-up game, this market will resolve 50-50.\nThe result will be determined based on the final score including any overtime periods and shootouts. In the event of a shootout, one goal will be added to the winning team\'s score for the purpose of resolution.',
#   'outcomes': '["Avalanche", "Golden Knights"]',
#   'outcomePrices': '["0.5", "0.5"]',
#   'active': True,
#   'closed': False,
#   'marketMakerAddress': '',
#   'createdAt': '2025-11-30T16:30:24.56499Z',
#   'updatedAt': '2025-12-01T00:23:55.868986Z',
#   'new': False,
#   'featured': False,
#   'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5',
#   'archived': False,
#   'resolvedBy': '0x65070BE91477460D8A7AeEb94ef92fe056C2f2A7',
#   'restricted': True,
#   'groupItemThreshold': '0',
#   'questionID': '0x2a9eca556b3475c6fbab4eeacd8f0d8e8b25670f4e6973fdfca86b45c2c43d80',
#   'enableOrderBook': True,
#   'orderPriceMinTickSize': 0.01,
#   'orderMinSize': 5,
#   'liquidityNum': 674.4976,
#   'endDateIso': '2025-12-28',
#   'startDateIso': '2025-11-30',
#   'hasReviewedDates': True,
#   'gameStartTime': '2025-12-28 03:00:00+00',
#   'secondsDelay': 3,
#   'clobTokenIds': '["29346012060431113509782169072762450203273267554865065778307900304994266442613", "60708587154919634428498746568272932211574027521859688246127712503166738844372"]',
#   'umaBond': '500',
#   'umaReward': '2',
#   'liquidityClob': 674.4976,
#   'customLiveness': 0,
#   'acceptingOrders': True,
#   'negRisk': False,
#   'negRiskRequestID': '',
#   'events': [{'id': '94255',
#     'ticker': 'nhl-col-las-2025-12-27',
#     'slug': 'nhl-col-las-2025-12-27',
#     'title': 'Avalanche vs. Golden Knights',
#     'description': 'In the upcoming NHL game, scheduled for December 27 at 10:00PM ET:\nIf the Avalanche win, the market will resolve to "Avalanche".\nIf the Golden Knights win, the market will resolve to "Golden Knights".\nIf the game is postponed, this market will remain open until the game has been completed.\nIf the game is canceled entirely, with no make-up game, this market will resolve 50-50.\nThe result will be determined based on the final score including any overtime periods and shootouts. In the event of a shootout, one goal will be added to the winning team\'s score for the purpose of resolution.',
#     'resolutionSource': 'https://www.nhl.com/scores',
#     'startDate': '2025-11-30T16:33:15.196499Z',
#     'creationDate': '2025-12-28T03:00:00Z',
#     'endDate': '2025-12-28T03:00:00Z',
#     'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#     'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#     'active': True,
#     'closed': False,
#     'archived': False,
#     'new': False,
#     'featured': False,
#     'restricted': True,
#     'liquidity': 674.4976,
#     'openInterest': 0,
#     'createdAt': '2025-11-30T16:30:24.561018Z',
#     'updatedAt': '2025-12-01T00:21:14.557647Z',
#     'competitive': 0.52,
#     'enableOrderBook': True,
#     'liquidityClob': 674.4976,
#     'negRisk': False,
#     'commentCount': 0,
#     'series': [{'id': '10346',
#       'ticker': 'nhl-2026',
#       'slug': 'nhl-2026',
#       'title': 'NHL 2026',
#       'seriesType': 'single',
#       'recurrence': 'daily',
#       'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#       'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#       'active': True,
#       'closed': False,
#       'archived': False,
#       'featured': False,
#       'restricted': True,
#       'createdAt': '2025-10-02T17:24:41.601549Z',
#       'updatedAt': '2025-12-01T00:21:36.186202Z',
#       'volume': 3557746.449572,
#       'liquidity': 1655526.99976,
#       'commentCount': 223361}],
#     'cyom': False,
#     'showAllOutcomes': True,
#     'showMarketImages': False,
#     'enableNegRisk': False,
#     'automaticallyActive': True,
#     'eventDate': '2025-12-27',
#     'startTime': '2025-12-28T03:00:00Z',
#     'eventWeek': 13,
#     'seriesSlug': 'nhl-2026',
#     'negRiskAugmented': False,
#     'pendingDeployment': False,
#     'deploying': False,
#     'gameId': 30024571}],
#   'ready': False,
#   'funded': False,
#   'acceptingOrdersTimestamp': '2025-11-30T16:31:14Z',
#   'cyom': False,
#   'competitive': 0.52,
#   'pagerDutyNotificationEnabled': False,
#   'approved': True,
#   'rewardsMinSize': 0,
#   'rewardsMaxSpread': 0,
#   'spread': 0.48,
#   'bestBid': 0.26,
#   'bestAsk': 0.74,
#   'automaticallyActive': True,
#   'clearBookOnStart': True,
#   'manualActivation': False,
#   'negRiskOther': False,
#   'sportsMarketType': 'moneyline',
#   'umaResolutionStatuses': '[]',
#   'pendingDeployment': False,
#   'deploying': False,
#   'deployingTimestamp': '2025-11-30T16:30:41.533452Z',
#   'rfqEnabled': False,
#   'holdingRewardsEnabled': False,
#   'feesEnabled': False},
#  {'id': '776047',
#   'question': 'Sharks vs. Canucks',
#   'conditionId': '0xa108d752349e7010aa8607732b305bc2450734342128e614f7cc8b670968a4d6',
#   'slug': 'nhl-sj-van-2025-12-27',
#   'resolutionSource': 'https://www.nhl.com/scores',
#   'endDate': '2025-12-28T03:00:00Z',
#   'liquidity': '674.4976',
#   'startDate': '2025-11-30T16:31:36.654858Z',
#   'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#   'description': 'In the upcoming NHL game, scheduled for December 27 at 10:00PM ET:\nIf the Sharks win, the market will resolve to "Sharks".\nIf the Canucks win, the market will resolve to "Canucks".\nIf the game is postponed, this market will remain open until the game has been completed.\nIf the game is canceled entirely, with no make-up game, this market will resolve 50-50.\nThe result will be determined based on the final score including any overtime periods and shootouts. In the event of a shootout, one goal will be added to the winning team\'s score for the purpose of resolution.',
#   'outcomes': '["Sharks", "Canucks"]',
#   'outcomePrices': '["0.5", "0.5"]',
#   'active': True,
#   'closed': False,
#   'marketMakerAddress': '',
#   'createdAt': '2025-11-30T16:30:25.090399Z',
#   'updatedAt': '2025-12-01T00:20:05.377386Z',
#   'new': False,
#   'featured': False,
#   'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5',
#   'archived': False,
#   'resolvedBy': '0x65070BE91477460D8A7AeEb94ef92fe056C2f2A7',
#   'restricted': True,
#   'groupItemThreshold': '0',
#   'questionID': '0xe75551e9e86a570371dabb85ce0b7616120e4e889924cbbf58a5e0ceec0a96f9',
#   'enableOrderBook': True,
#   'orderPriceMinTickSize': 0.01,
#   'orderMinSize': 5,
#   'liquidityNum': 674.4976,
#   'endDateIso': '2025-12-28',
#   'startDateIso': '2025-11-30',
#   'hasReviewedDates': True,
#   'gameStartTime': '2025-12-28 03:00:00+00',
#   'secondsDelay': 3,
#   'clobTokenIds': '["112033601050615219362939615600930915669957024863247284628872883546735869478542", "73129994871112216673504744340178714313940340168846711936957221283294551100019"]',
#   'umaBond': '500',
#   'umaReward': '2',
#   'liquidityClob': 674.4976,
#   'customLiveness': 0,
#   'acceptingOrders': True,
#   'negRisk': False,
#   'negRiskRequestID': '',
#   'events': [{'id': '94256',
#     'ticker': 'nhl-sj-van-2025-12-27',
#     'slug': 'nhl-sj-van-2025-12-27',
#     'title': 'Sharks vs. Canucks',
#     'description': 'In the upcoming NHL game, scheduled for December 27 at 10:00PM ET:\nIf the Sharks win, the market will resolve to "Sharks".\nIf the Canucks win, the market will resolve to "Canucks".\nIf the game is postponed, this market will remain open until the game has been completed.\nIf the game is canceled entirely, with no make-up game, this market will resolve 50-50.\nThe result will be determined based on the final score including any overtime periods and shootouts. In the event of a shootout, one goal will be added to the winning team\'s score for the purpose of resolution.',
#     'resolutionSource': 'https://www.nhl.com/scores',
#     'startDate': '2025-11-30T16:33:15.103817Z',
#     'creationDate': '2025-12-28T03:00:00Z',
#     'endDate': '2025-12-28T03:00:00Z',
#     'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#     'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#     'active': True,
#     'closed': False,
#     'archived': False,
#     'new': False,
#     'featured': False,
#     'restricted': True,
#     'liquidity': 674.4976,
#     'openInterest': 0,
#     'createdAt': '2025-11-30T16:30:25.08667Z',
#     'updatedAt': '2025-12-01T00:21:16.266501Z',
#     'competitive': 0.52,
#     'enableOrderBook': True,
#     'liquidityClob': 674.4976,
#     'negRisk': False,
#     'commentCount': 0,
#     'series': [{'id': '10346',
#       'ticker': 'nhl-2026',
#       'slug': 'nhl-2026',
#       'title': 'NHL 2026',
#       'seriesType': 'single',
#       'recurrence': 'daily',
#       'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#       'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#       'active': True,
#       'closed': False,
#       'archived': False,
#       'featured': False,
#       'restricted': True,
#       'createdAt': '2025-10-02T17:24:41.601549Z',
#       'updatedAt': '2025-12-01T00:21:36.186202Z',
#       'volume': 3557746.449572,
#       'liquidity': 1655526.99976,
#       'commentCount': 223361}],
#     'cyom': False,
#     'showAllOutcomes': True,
#     'showMarketImages': False,
#     'enableNegRisk': False,
#     'automaticallyActive': True,
#     'eventDate': '2025-12-27',
#     'startTime': '2025-12-28T03:00:00Z',
#     'eventWeek': 13,
#     'seriesSlug': 'nhl-2026',
#     'negRiskAugmented': False,
#     'pendingDeployment': False,
#     'deploying': False,
#     'gameId': 30024572}],
#   'ready': False,
#   'funded': False,
#   'acceptingOrdersTimestamp': '2025-11-30T16:31:14Z',
#   'cyom': False,
#   'competitive': 0.52,
#   'pagerDutyNotificationEnabled': False,
#   'approved': True,
#   'rewardsMinSize': 0,
#   'rewardsMaxSpread': 0,
#   'spread': 0.48,
#   'bestBid': 0.26,
#   'bestAsk': 0.74,
#   'automaticallyActive': True,
#   'clearBookOnStart': True,
#   'manualActivation': False,
#   'negRiskOther': False,
#   'sportsMarketType': 'moneyline',
#   'umaResolutionStatuses': '[]',
#   'pendingDeployment': False,
#   'deploying': False,
#   'deployingTimestamp': '2025-11-30T16:30:41.538768Z',
#   'rfqEnabled': False,
#   'holdingRewardsEnabled': False,
#   'feesEnabled': False},
#  {'id': '776048',
#   'question': 'Oilers vs. Flames',
#   'conditionId': '0x3d868c161e4ddfccf2a21136e63081f54bf86b2cc934cb59da4832ab9fe7bef9',
#   'slug': 'nhl-edm-cal-2025-12-27',
#   'resolutionSource': 'https://www.nhl.com/scores',
#   'endDate': '2025-12-28T03:00:00Z',
#   'liquidity': '752.4977',
#   'startDate': '2025-11-30T16:31:36.910799Z',
#   'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#   'description': 'In the upcoming NHL game, scheduled for December 27 at 10:00PM ET:\nIf the Oilers win, the market will resolve to "Oilers".\nIf the Flames win, the market will resolve to "Flames".\nIf the game is postponed, this market will remain open until the game has been completed.\nIf the game is canceled entirely, with no make-up game, this market will resolve 50-50.\nThe result will be determined based on the final score including any overtime periods and shootouts. In the event of a shootout, one goal will be added to the winning team\'s score for the purpose of resolution.',
#   'outcomes': '["Oilers", "Flames"]',
#   'outcomePrices': '["0.52", "0.48"]',
#   'active': True,
#   'closed': False,
#   'marketMakerAddress': '',
#   'createdAt': '2025-11-30T16:30:25.602657Z',
#   'updatedAt': '2025-12-01T00:24:44.017484Z',
#   'new': False,
#   'featured': False,
#   'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5',
#   'archived': False,
#   'resolvedBy': '0x65070BE91477460D8A7AeEb94ef92fe056C2f2A7',
#   'restricted': True,
#   'groupItemThreshold': '0',
#   'questionID': '0x61cdc820f547499e48955d79eac6bdedcaa324c8ae6642a591f1df72e6abcde3',
#   'enableOrderBook': True,
#   'orderPriceMinTickSize': 0.01,
#   'orderMinSize': 5,
#   'liquidityNum': 752.4977,
#   'endDateIso': '2025-12-28',
#   'startDateIso': '2025-11-30',
#   'hasReviewedDates': True,
#   'gameStartTime': '2025-12-28 03:00:00+00',
#   'secondsDelay': 3,
#   'clobTokenIds': '["111379626375402079288367888117145839947193656774168699338013408671326399094120", "51042718924618174402979753797612250225864393240910557403415048435898141894556"]',
#   'umaBond': '500',
#   'umaReward': '2',
#   'liquidityClob': 752.4977,
#   'customLiveness': 0,
#   'acceptingOrders': True,
#   'negRisk': False,
#   'negRiskRequestID': '',
#   'events': [{'id': '94257',
#     'ticker': 'nhl-edm-cal-2025-12-27',
#     'slug': 'nhl-edm-cal-2025-12-27',
#     'title': 'Oilers vs. Flames',
#     'description': 'In the upcoming NHL game, scheduled for December 27 at 10:00PM ET:\nIf the Oilers win, the market will resolve to "Oilers".\nIf the Flames win, the market will resolve to "Flames".\nIf the game is postponed, this market will remain open until the game has been completed.\nIf the game is canceled entirely, with no make-up game, this market will resolve 50-50.\nThe result will be determined based on the final score including any overtime periods and shootouts. In the event of a shootout, one goal will be added to the winning team\'s score for the purpose of resolution.',
#     'resolutionSource': 'https://www.nhl.com/scores',
#     'startDate': '2025-11-30T16:33:15.108216Z',
#     'creationDate': '2025-12-28T03:00:00Z',
#     'endDate': '2025-12-28T03:00:00Z',
#     'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#     'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#     'active': True,
#     'closed': False,
#     'archived': False,
#     'new': False,
#     'featured': False,
#     'restricted': True,
#     'liquidity': 752.4977,
#     'openInterest': 0,
#     'createdAt': '2025-11-30T16:30:25.598668Z',
#     'updatedAt': '2025-12-01T00:21:28.045964Z',
#     'competitive': 0.5597760895641744,
#     'enableOrderBook': True,
#     'liquidityClob': 752.4977,
#     'negRisk': False,
#     'commentCount': 0,
#     'series': [{'id': '10346',
#       'ticker': 'nhl-2026',
#       'slug': 'nhl-2026',
#       'title': 'NHL 2026',
#       'seriesType': 'single',
#       'recurrence': 'daily',
#       'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#       'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#       'active': True,
#       'closed': False,
#       'archived': False,
#       'featured': False,
#       'restricted': True,
#       'createdAt': '2025-10-02T17:24:41.601549Z',
#       'updatedAt': '2025-12-01T00:21:36.186202Z',
#       'volume': 3557746.449572,
#       'liquidity': 1655526.99976,
#       'commentCount': 223361}],
#     'cyom': False,
#     'showAllOutcomes': True,
#     'showMarketImages': False,
#     'enableNegRisk': False,
#     'automaticallyActive': True,
#     'eventDate': '2025-12-27',
#     'startTime': '2025-12-28T03:00:00Z',
#     'eventWeek': 13,
#     'seriesSlug': 'nhl-2026',
#     'negRiskAugmented': False,
#     'pendingDeployment': False,
#     'deploying': False,
#     'gameId': 30024573}],
#   'ready': False,
#   'funded': False,
#   'acceptingOrdersTimestamp': '2025-11-30T16:31:14Z',
#   'cyom': False,
#   'competitive': 0.5597760895641744,
#   'pagerDutyNotificationEnabled': False,
#   'approved': True,
#   'rewardsMinSize': 0,
#   'rewardsMaxSpread': 0,
#   'spread': 0.44,
#   'oneHourPriceChange': 0.02,
#   'bestBid': 0.3,
#   'bestAsk': 0.74,
#   'automaticallyActive': True,
#   'clearBookOnStart': True,
#   'manualActivation': False,
#   'negRiskOther': False,
#   'sportsMarketType': 'moneyline',
#   'umaResolutionStatuses': '[]',
#   'pendingDeployment': False,
#   'deploying': False,
#   'deployingTimestamp': '2025-11-30T16:30:41.541375Z',
#   'rfqEnabled': False,
#   'holdingRewardsEnabled': False,
#   'feesEnabled': False}]

# %%
sport_tag_id
# Out:
# 306

# %%
spprt_tag
# Out:
# {'type': 'not found error', 'error': 'slug not found'}

# %%
for i in range(6, 5):
    print(i)

# %%
alive_mkt[0]
# Out:
# {'id': '605042',
#  'question': 'Oilers vs. Flames',
#  'conditionId': '0x1ec664b73bf312e2a2ca693deb94e126dd74b5dfa44bc9cedf1e8129ebe8652a',
#  'slug': 'nhl-edm-cgy-2025-09-21',
#  'resolutionSource': 'https://www.nhl.com/scores',
#  'endDate': '2025-09-22T00:00:00Z',
#  'liquidity': '5.9566',
#  'startDate': '2025-09-20T06:22:02.212099Z',
#  'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#  'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#  'description': 'In the upcoming NHL game, scheduled for September 21 at 8:00PM ET:\nIf the Oilers, the market will resolve to "Oilers".\nIf the Flames, the market will resolve to "Flames".\nIf the game is postponed, this market will remain open until the game has been completed.\nIf the game is canceled entirely, with no make-up game, this market will resolve 50-50.',
#  'outcomes': '["Oilers", "Flames"]',
#  'outcomePrices': '["0.5", "0.5"]',
#  'volume': '510.615132',
#  'active': True,
#  'closed': False,
#  'marketMakerAddress': '',
#  'createdAt': '2025-09-20T06:20:47.807041Z',
#  'updatedAt': '2025-11-09T21:28:13.195749Z',
#  'new': False,
#  'featured': False,
#  'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5',
#  'archived': False,
#  'resolvedBy': '0x65070BE91477460D8A7AeEb94ef92fe056C2f2A7',
#  'restricted': True,
#  'groupItemThreshold': '0',
#  'questionID': '0x2a19d7739a45ba64d79083143e78b98211f29b92a14a04d6ceb3311672cde337',
#  'enableOrderBook': True,
#  'orderPriceMinTickSize': 0.01,
#  'orderMinSize': 5,
#  'volumeNum': 510.615132,
#  'liquidityNum': 5.9566,
#  'endDateIso': '2025-09-22',
#  'startDateIso': '2025-09-20',
#  'hasReviewedDates': True,
#  'volume1wk': 1.01,
#  'volume1mo': 9.605032,
#  'volume1yr': 510.615132,
#  'gameStartTime': '2025-09-22 00:00:00+00',
#  'secondsDelay': 3,
#  'clobTokenIds': '["52205886726417997587062732777226140886318278712083909477105055938757753833806", "55605869039173595146985121120073582626202060075897859340246557957762365711817"]',
#  'umaBond': '500',
#  'umaReward': '2',
#  'volume1wkClob': 1.01,
#  'volume1moClob': 9.605032,
#  'volume1yrClob': 510.615132,
#  'volumeClob': 510.615132,
#  'liquidityClob': 5.9566,
#  'customLiveness': 0,
#  'acceptingOrders': True,
#  'negRisk': False,
#  'negRiskRequestID': '',
#  'events': [{'id': '47061',
#    'ticker': 'nhl-edm-cgy-2025-09-21',
#    'slug': 'nhl-edm-cgy-2025-09-21',
#    'title': 'Oilers vs. Flames',
#    'description': 'In the upcoming NHL game, scheduled for September 21 at 8:00PM ET:\nIf the Oilers, the market will resolve to "Oilers".\nIf the Flames, the market will resolve to "Flames".\nIf the game is postponed, this market will remain open until the game has been completed.\nIf the game is canceled entirely, with no make-up game, this market will resolve 50-50.',
#    'resolutionSource': 'https://www.nhl.com/scores',
#    'startDate': '2025-09-20T06:23:20.860618Z',
#    'creationDate': '2025-09-22T00:00:00Z',
#    'endDate': '2025-09-22T00:00:00Z',
#    'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#    'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#    'active': True,
#    'closed': False,
#    'archived': False,
#    'new': False,
#    'featured': False,
#    'restricted': True,
#    'liquidity': 5.9566,
#    'volume': 510.615132,
#    'openInterest': 0,
#    'createdAt': '2025-09-20T06:20:47.702057Z',
#    'updatedAt': '2025-11-09T21:20:32.44924Z',
#    'competitive': 0.04,
#    'volume1wk': 1.01,
#    'volume1mo': 9.605032,
#    'volume1yr': 510.615132,
#    'enableOrderBook': True,
#    'liquidityClob': 5.9566,
#    'negRisk': False,
#    'commentCount': 0,
#    'cyom': False,
#    'showAllOutcomes': True,
#    'showMarketImages': False,
#    'enableNegRisk': False,
#    'automaticallyActive': True,
#    'eventDate': '2025-09-21',
#    'eventWeek': 50,
#    'negRiskAugmented': False,
#    'pendingDeployment': False,
#    'deploying': False,
#    'gameId': 23946}],
#  'ready': False,
#  'funded': False,
#  'acceptingOrdersTimestamp': '2025-09-20T06:21:40Z',
#  'cyom': False,
#  'competitive': 0.04,
#  'pagerDutyNotificationEnabled': False,
#  'approved': True,
#  'rewardsMinSize': 0,
#  'rewardsMaxSpread': 0,
#  'spread': 0.96,
#  'lastTradePrice': 0.02,
#  'bestBid': 0.02,
#  'bestAsk': 0.98,
#  'automaticallyActive': True,
#  'clearBookOnStart': True,
#  'manualActivation': False,
#  'negRiskOther': False,
#  'sportsMarketType': 'moneyline',
#  'umaResolutionStatuses': '[]',
#  'pendingDeployment': False,
#  'deploying': False,
#  'deployingTimestamp': '2025-09-20T06:21:04.875213Z',
#  'rfqEnabled': False,
#  'holdingRewardsEnabled': False,
#  'feesEnabled': False}

# %%
import pandas as pd
# Out:
# C:\Users\zhang\AppData\Local\Temp\ipykernel_8160\217833862.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
s1 = pd.Series({'a':1,'b':2} )
s2 = pd.Series({'a':3,'b':4} )

# %%
s1
# Out:
# a    1
# b    2
# dtype: int64

# %%
pd.DataFrame([s1, s2])
# Out:
#    a  b
# 0  1  2
# 1  3  4

# %%
def add_formula_params(curr_df, midpoint, v, daily_reward):
    curr_df['s'] = (curr_df['price'] - midpoint).abs()
    curr_df['S'] = ((v - curr_df['s']) / v) ** 2
    curr_df['100'] = 1/curr_df['price'] * 100

    curr_df['size'] = curr_df['size'] + curr_df['100']

    curr_df['Q'] = curr_df['S'] * curr_df['size']
    curr_df['reward_per_100'] = (curr_df['Q'] / curr_df['Q'].sum()) * daily_reward / 2 / curr_df['size'] * curr_df['100']
    return curr_df

def process_single_row(row, client):
    ret = {}
    ret['question'] = row['question']
    ret['neg_risk'] = row['neg_risk']

    ret['answer1'] = row['tokens'][0]['outcome']
    ret['answer2'] = row['tokens'][1]['outcome']

    ret['min_size'] = row['rewards']['min_size']
    ret['max_spread'] = row['rewards']['max_spread']

    token1 = row['tokens'][0]['token_id']
    token2 = row['tokens'][1]['token_id']

    rate = 0
    for rate_info in row['rewards']['rates']:
        if rate_info['asset_address'].lower() == '0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174'.lower():
            rate = rate_info['rewards_daily_rate']
            break

    ret['rewards_daily_rate'] = rate
    book = client.get_order_book(token1)
    
    bids = pd.DataFrame()
    asks = pd.DataFrame()

    try:
        bids = pd.DataFrame(book.bids).astype(float)
    except:
        pass

    try:
        asks = pd.DataFrame(book.asks).astype(float)
    except:
        pass


    try:
        ret['best_bid'] = bids.iloc[-1]['price']
    except:
        ret['best_bid'] = 0

    try:
        ret['best_ask'] = asks.iloc[-1]['price']
    except:
        ret['best_ask'] = 0

    ret['midpoint'] = (ret['best_bid'] + ret['best_ask']) / 2
    
    TICK_SIZE = row['minimum_tick_size']
    ret['tick_size'] = TICK_SIZE

    bid_from, bid_to, ask_from, ask_to = get_bid_ask_range(ret, TICK_SIZE)
    v = round((ret['max_spread'] / 100), 2)

    bids_df = pd.DataFrame()
    bids_df['price'] = generate_numbers(bid_from, bid_to, TICK_SIZE)

    asks_df = pd.DataFrame()
    asks_df['price'] = generate_numbers(ask_from, ask_to, TICK_SIZE)

    try:
        bids_df = bids_df.merge(bids, on='price', how='left').fillna(0)
    except:
        bids_df = pd.DataFrame()

    try:
        asks_df = asks_df.merge(asks, on='price', how='left').fillna(0)
    except:
        asks_df = pd.DataFrame()

    best_bid_reward = 0
    ret_bid = pd.DataFrame()

    try:
        ret_bid = add_formula_params(bids_df, ret['midpoint'], v, rate)
        best_bid_reward = round(ret_bid['reward_per_100'].max(), 2)
    except:
        pass

    best_ask_reward = 0
    ret_ask = pd.DataFrame()

    try:
        ret_ask = add_formula_params(asks_df, ret['midpoint'], v, rate)
        best_ask_reward = round(ret_ask['reward_per_100'].max(), 2)
    except:
        pass

    ret['bid_reward_per_100'] = best_bid_reward
    ret['ask_reward_per_100'] = best_ask_reward

    ret['sm_reward_per_100'] = round((best_bid_reward + best_ask_reward) / 2, 2)
    ret['gm_reward_per_100'] = round((best_bid_reward * best_ask_reward) ** 0.5, 2)

    ret['end_date_iso'] = row['end_date_iso']
    ret['market_slug'] = row['market_slug']
    ret['token1'] = token1
    ret['token2'] = token2
    ret['condition_id'] = row['condition_id']

    return ret

# %%
import pandas as pd
# Out:
# C:\Users\zhang\AppData\Local\Temp\ipykernel_11484\217833862.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
d = [{'price': '0.01', 'size': '2317.49'}, {'price': '0.02', 'size': '150'}, {'price': '0.03', 'size': '12.64'}, {'price': '0.04', 'size': '16880'}, {'price': '0.05', 'size': '150'}, {'price': '0.06', 'size': '383.33'}, {'price': '0.07', 'size': '9174.57'}, {'price': '0.08', 'size': '5.5'}, {'price': '0.1', 'size': '5640'}, {'price': '0.12', 'size': '3030'}, {'price': '0.13', 'size': '9784'}, {'price': '0.14', 'size': '65720.86'}, {'price': '0.15', 'size': '122838.31'}, {'price': '0.16', 'size': '155505.4'}, {'price': '0.17', 'size': '60848.9'}]

# %%
df = pd.DataFrame(d)

# %%
from decimal import Decimal
round(Decimal('0.78'), 5)
# Out:
# Decimal('0.78000')
